# %%
# Import dependencies.
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read in our data
equities_df = pd.read_csv("resources/post831.csv")

# %%
stock = str(input("What stock would you like to look at?")).upper()
# Out:
# What stock would you like to look at?tsla

# %%
df = equities_df.loc[equities_df['symbol'] == stock]

# %%
df.head()
# Out:
#       symbol      date    high  iexClose        industry      low  \
# 7088    TSLA  9/1/2020  502.49    482.10  Motor Vehicles  470.510
# 14980   TSLA  9/2/2020  479.04    440.68  Motor Vehicles  405.121
# 22872   TSLA  9/3/2020  431.80    409.71  Motor Vehicles  405.000
# 30764   TSLA  9/8/2020  368.74    355.88  Motor Vehicles  335.990
# 38653   TSLA  9/9/2020  364.99    348.89  Motor Vehicles  341.580
#
#                   sector    volume   death  deathIncrease  \
# 7088   Consumer Durables  62104997  176765           1014
# 14980  Consumer Durables  79430265  177800           1035
# 22872  Consumer Durables  60192580  178872           1072
# 30764  Consumer Durables  64952323  181823            347
# 38653  Consumer Durables  46066580  182911           1088
#
#        hospitalizedIncrease  hospitalizedCurrently  negative  \
# 7088                   1867                  35338  27247822
# 14980                  1521                  35661  27458919
# 22872                  1488                  34753  27686000
# 30764                   987                  32255  28682346
# 38653                  1918                  32670  28875758
#
#        negativeIncrease  positive  positiveIncrease  totalTestResults  \
# 7088             179210   6022681             42242          87045462
# 14980            211097   6053348             30667          87841607
# 22872            227081   6097979             44631          88751427
# 30764            123290   6277899             22310          92816319
# 38653            193412   6308655             30756          93567321
#
#        totalTestResultsIncrease
# 7088                     796530
# 14980                    796145
# 22872                    909820
# 30764                    546859
# 38653                    751002

# %%
# Create Xaxis for Date
x_axis = df["date"]
# Create Yaxis for stock price
y_axis = df["iexClose"]
# Create Zaxis for Covid deaths
y2_axis = df["hospitalizedIncrease"]

#Set chart size
plt.rcParams["figure.figsize"] = (20,6)

# %%
x_axis.head()
# Out:
# 7088     9/1/2020
# 14980    9/2/2020
# 22872    9/3/2020
# 30764    9/8/2020
# 38653    9/9/2020
# Name: date, dtype: object

# %%
# Create stock line chart
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label=stock)

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("$Value")
plt.xticks(rotation=45)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
plt.title(stock)
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create stock bar plot.
plt.bar(x_axis, y_axis, color="green", label=stock)

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Value")
plt.xticks(rotation=45)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
plt.title(stock)
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="^", color="blue", linewidth=1, label=stock)
plt.plot(x_axis, y2_axis, marker="*", color="red", linewidth=1, label='hospitalizedIncrease')

#Set chart size
# plt.rcParams["figure.figsize"] = (20,6)

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("$Value")
plt.xticks(rotation=45)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
plt.title("Stock vs hospitalizedIncrease")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(x_axis, y_axis, color="blue", marker="^", linewidth=1, label=stock)

# set x-axis label
ax.set_xlabel("Date", fontsize = 20)
plt.xticks(rotation=45)
# set y-axis label
ax.set_ylabel("Stock Price $", color="blue", fontsize=24)
plt.legend(loc = "lower left")

# twin object for two y-axis on the plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="red",marker="*",linewidth=1, label='Hospitalized Increase')
ax2.set_ylabel("Hospitalized Increase",color="red",fontsize=24)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
title = stock + " vs Hospitalized Increase"
plt.title(title,fontsize=24)

# Add a grid.
plt.grid()
# Add the legend.
plt.legend(loc = "best")



plt.show()

# %%
# Create File Name
format = ".png"
hospital = "_hospitalized_Increase"
SaveAs = stock + hospital + format

# save the plot as a jpeg
fig.savefig(SaveAs, format='png', dpi=100, bbox_inches='tight')
