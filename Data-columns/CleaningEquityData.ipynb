# %%
import pandas as pd
import os

# %%
raw_equity_df = pd.read_csv("../Data/equities.csv.csv")
raw_equity_df.head()
# Out:
# C:\Users\tdemo\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (51,69,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   symbol       date                   CEO             address address2  \
# 0   PJUL  8_19_2020                   NaN                 NaN      NaN
# 1    PIM  8_19_2020   Jonathan S. Horwitz  100 Federal Street      NaN
# 2    PJH  8_19_2020     Charlie F. Lowrey    751 Broad Street      NaN
# 3    PJT  8_19_2020  Paul Jeffrey Taubman     280 Park Avenue      NaN
# 4   PKBK  8_19_2020    Vito S. Pantilione    601 Delsea Drive      NaN
#
#    avg10Volume  avg30Volume  avgTotalVolume      beta calculationPrice  ...  \
# 0      12719.0     35172.73         35173.0  0.525089              sip  ...
# 1      83343.8    111572.17        111572.0  0.554207              sip  ...
# ...

# %%
list(raw_equity_df.columns)
# Out:
# ['symbol',
#  'date',
#  'CEO',
#  'address',
#  'address2',
#  'avg10Volume',
#  'avg30Volume',
#  'avgTotalVolume',
#  'beta',
#  'calculationPrice',
#  'change',
#  'changePercent',
#  'city',
#  'close',
#  'closeSource',
#  'closeTime',
#  'companyName',
#  'country',
#  'day200MovingAvg',
#  'day30ChangePercent',
#  'day50MovingAvg',
#  'day5ChangePercent',
#  'delayedPrice',
#  'delayedPriceTime',
#  'description',
#  'dividendYield',
#  'employees',
#  'exDividendDate',
#  'exchange',
#  'extendedChange',
#  'extendedChangePercent',
#  'extendedPrice',
#  'extendedPriceTime',
#  'float',
#  'high',
#  'highSource',
#  'highTime',
#  'iexAskPrice',
#  'iexAskSize',
#  'iexBidPrice',
#  'iexBidSize',
#  'iexClose',
#  'iexCloseTime',
#  'iexLastUpdated',
#  'iexMarketPercent',
#  'iexOpen',
#  'iexOpenTime',
#  'iexRealtimePrice',
#  'iexRealtimeSize',
#  'iexVolume',
#  'industry',
#  'isUSMarketOpen',
#  'issueType',
#  'lastTradeTime',
#  'latestPrice',
#  'latestSource',
# ...

# %%
equity_df = raw_equity_df[['symbol', 'date', 'change', 'changePercent', 'close', 'high',
                          'iexClose','industry', 'low','marketCap','maxChangePercent','open','sector','volume']]
equity_df
# Out:
#        symbol        date  change  changePercent   close    high  iexClose  \
# 0        PJUL   8_19_2020   0.020        0.00072  27.779  27.840    27.710
# 1         PIM   8_19_2020  -0.030       -0.00704   4.260   4.260     4.240
# 2         PJH   8_19_2020  -0.004       -0.00016  25.370  25.450    25.365
# 3         PJT   8_19_2020  -0.135       -0.00229  59.020  59.670    58.885
# 4        PKBK   8_19_2020   0.640        0.04992     NaN  13.460    13.460
# ...       ...         ...     ...            ...     ...     ...       ...
# 690318    ZVO  12_23_2020  -0.020       -0.00483   4.120   4.270     4.130
# 690319    ZSL  12_23_2020  -0.260       -0.03444   7.290   7.380     7.310
# 690320   ZYNE  12_23_2020  -0.030       -0.00872   3.410   3.505     3.415
# 690321   ZYME  12_23_2020  -2.040       -0.03845  51.010  53.700    51.030
# 690322   ZYXI  12_23_2020  -0.380       -0.02678  13.810  14.490    13.820
#
#                                                  industry     low  \
# ...

# %%
equity_df.to_csv(r'EQUITY_DATA_COLUMNS.csv')

# %%
equity_df.dtypes
# Out:
# symbol               object
# date                 object
# change              float64
# changePercent       float64
# close               float64
# high                float64
# iexClose            float64
# industry             object
# low                 float64
# marketCap           float64
# maxChangePercent    float64
# open                float64
# sector               object
# volume                int64
# dtype: object
