# %%
# Import dependencies.
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read in our data
equities_df = pd.read_csv("resources/cleaned_close.csv")

# %%
stock_df = equities_df.loc[equities_df['symbol'] == "TSLA"]

# %%
stock_df.head()
# Out:
#       symbol       date     high  iexClose        industry      low  \
# 3116    TSLA  8/19/2020  1911.00  1901.900  Motor Vehicles  1841.21
# 14982   TSLA  8/20/2020  1997.00  1989.170  Motor Vehicles  1857.06
# 22872   TSLA  8/21/2020  2095.69  2048.190  Motor Vehicles  2025.05
# 30765   TSLA  8/24/2020  2129.00  2006.440  Motor Vehicles  1927.52
# 38659   TSLA  8/25/2020  2027.95  2003.305  Motor Vehicles  1968.00
#
#                   sector    volume   death  deathIncrease  \
# 3116   Consumer Durables   8444118  165088           1411
# 14982  Consumer Durables  10981822  166217           1129
# 22872  Consumer Durables  19864088  167336           1119
# 30765  Consumer Durables  16233690  169289            341
# 38659  Consumer Durables   8551503  170429           1140
#
#        hospitalizedIncrease  hospitalizedCurrently  negative  \
# 3116                   1983                  43406  24462674
# 14982                  1983                  42109  24671146
# ...

# %%
x_axis = stock_df["date"]
y_axis = stock_df["iexClose"]

# %%
x_axis.head()
# Out:
# 3116     8/19/2020
# 14982    8/20/2020
# 22872    8/21/2020
# 30765    8/24/2020
# 38659    8/25/2020
# Name: date, dtype: object

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='TSLA')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Value")
# Set the y limit between 0 and 4000.
plt.ylim(0, 2500)
# Create a title.
plt.title("TSLA Stock")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='TSLA')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Value")
# Set the y limit between 0 and 4000.
plt.ylim(0, 2500)
# Create a title.
plt.title("TSLA Stock")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create bar plot.
plt.bar(x_axis, y_axis, color="green", label='TSLA')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Value")
# Create a title.
plt.title("TSLA Stock")
# Add the legend.
plt.legend()

# %%
# Create axis for Covid deaths
z_axis = stock_df["deathIncrease"]

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="^", color="blue", linewidth=1, label='TSLA')
plt.plot(x_axis, z_axis, marker="*", color="red", linewidth=1, label='Covid Deaths')

plt.xticks(rotation=45)
# plt.subplots_adjust(bottom=0.01)
# plt.xticks(rotation=45, ha='right')

# plt.xlim(9/1/2022, 12/28/20)
# plt.xlim(0, 40)
plt.rcParams["figure.figsize"] = (20,6)


# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("$Value")
# Set the y limit between 0 and 4000.
plt.ylim(0, 4000)
# Create a title.
plt.title("AAPL Stock vs Covid Deaths")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()
