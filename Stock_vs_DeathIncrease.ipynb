# %%
# Import dependencies.
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read in our data
equities_df = pd.read_csv("resources/post831.csv")

# %%
stock = str(input("What stock would you like to look at?")).upper()
# Out:
# What stock would you like to look at?AMD

# %%
df = equities_df.loc[equities_df['symbol'] == stock]

# %%
df.head()
# Out:
#       symbol      date   high  iexClose        industry    low  \
# 290      AMD  9/1/2020  92.51    91.530  Semiconductors  90.19
# 8181     AMD  9/2/2020  94.28    90.315  Semiconductors  88.74
# 16074    AMD  9/3/2020  88.47    83.355  Semiconductors  82.38
# 23966    AMD  9/8/2020  81.83    80.000  Semiconductors  78.00
# 31858    AMD  9/9/2020  81.73    80.860  Semiconductors  79.28
#
#                       sector    volume   death  deathIncrease  \
# 290    Electronic Technology  33287143  176765           1014
# 8181   Electronic Technology  39576337  177800           1035
# 16074  Electronic Technology  57767555  178872           1072
# 23966  Electronic Technology  28071735  181823            347
# 31858  Electronic Technology  25764456  182911           1088
#
#        hospitalizedIncrease  hospitalizedCurrently  negative  \
# 290                    1867                  35338  27247822
# 8181                   1521                  35661  27458919
# 16074                  1488                  34753  27686000
# 23966                   987                  32255  28682346
# 31858                  1918                  32670  28875758
#
#        negativeIncrease  positive  positiveIncrease  totalTestResults  \
# 290              179210   6022681             42242          87045462
# 8181             211097   6053348             30667          87841607
# 16074            227081   6097979             44631          88751427
# 23966            123290   6277899             22310          92816319
# 31858            193412   6308655             30756          93567321
#
#        totalTestResultsIncrease
# 290                      796530
# 8181                     796145
# 16074                    909820
# 23966                    546859
# 31858                    751002

# %%
# Create Xaxis for Date
x_axis = df["date"]
# Create Yaxis for stock price
y_axis = df["iexClose"]
# Create Zaxis for Covid deaths
y2_axis = df["deathIncrease"]

#Set chart size
plt.rcParams["figure.figsize"] = (20,6)

# %%
x_axis.head()
# Out:
# 290      9/1/2020
# 8181     9/2/2020
# 16074    9/3/2020
# 23966    9/8/2020
# 31858    9/9/2020
# Name: date, dtype: object

# %%
# Create stock line chart
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label=stock)

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("$Value")
plt.xticks(rotation=45)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
plt.title(stock)
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create stock bar plot.
plt.bar(x_axis, y_axis, color="green", label=stock)

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Value")
plt.xticks(rotation=45)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
plt.title(stock)
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="^", color="blue", linewidth=1, label=stock)
plt.plot(x_axis, y2_axis, marker="*", color="red", linewidth=1, label='deathIncrease')

#Set chart size
# plt.rcParams["figure.figsize"] = (20,6)

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("$Value")
plt.xticks(rotation=45)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
plt.title("Stock vs Covid_Deaths")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(x_axis, y_axis, color="blue", marker="^", linewidth=1, label=stock)

# set x-axis label
ax.set_xlabel("Date", fontsize = 20)
plt.xticks(rotation=45)
# set y-axis label
ax.set_ylabel("Stock Price $", color="blue", fontsize=24)
plt.legend(loc = "lower left")

# twin object for two y-axis on the plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="red",marker="*",linewidth=1, label='Death Increase')
ax2.set_ylabel("Death Increase",color="red",fontsize=24)

# Set the y to autoscale
plt.autoscale(enable=True, axis='y')

# Create a title.
title = stock + " vs Death Increase"
plt.title(title,fontsize=24)

# Add a grid.
plt.grid()
# Add the legend.
plt.legend(loc = "best")



plt.show()

# %%
# Create File Name
format = ".JPG"
deathIncrease = "_deathIncrease"
SaveAs = stock + deathIncrease + format

# save the plot as a jpeg
fig.savefig(SaveAs, format='jpeg', dpi=100, bbox_inches='tight')
