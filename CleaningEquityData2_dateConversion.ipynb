# %%
import os
import pandas as pd

# %%
raw_equity_df = pd.read_csv("../EDA/EQUITY_DATA_COLUMNS.csv")
raw_equity_df.head()
# Out:
#    Unnamed: 0 symbol       date  change  changePercent   close   high  \
# 0           0   PJUL  8_19_2020   0.020        0.00072  27.779  27.84
# 1           1    PIM  8_19_2020  -0.030       -0.00704   4.260   4.26
# 2           2    PJH  8_19_2020  -0.004       -0.00016  25.370  25.45
# 3           3    PJT  8_19_2020  -0.135       -0.00229  59.020  59.67
# 4           4   PKBK  8_19_2020   0.640        0.04992     NaN  13.46
#
#    iexClose                        industry    low     marketCap  \
# 0    27.710  Investment Trusts/Mutual Funds  27.76  1.160650e+08
# 1     4.240  Investment Trusts/Mutual Funds   4.23  2.190971e+08
# 2    25.365         Financial Conglomerates  25.35  1.001957e+10
# 3    58.885        Investment Banks/Brokers  58.60  1.415189e+09
# 4    13.460                  Regional Banks  12.89  1.594889e+08
#
#    maxChangePercent    open         sector  volume
# 0            0.0494  27.779  Miscellaneous    3283
# ...

# %%
raw_equity_df.tail()
# Out:
#         Unnamed: 0 symbol        date  change  changePercent  close    high  \
# 690318      690318    ZVO  12_23_2020   -0.02       -0.00483   4.12   4.270
# 690319      690319    ZSL  12_23_2020   -0.26       -0.03444   7.29   7.380
# 690320      690320   ZYNE  12_23_2020   -0.03       -0.00872   3.41   3.505
# 690321      690321   ZYME  12_23_2020   -2.04       -0.03845  51.01  53.700
# 690322      690322   ZYXI  12_23_2020   -0.38       -0.02678  13.81  14.490
#
#         iexClose                                           industry     low  \
# 690318     4.130  Colleges, Universities, and Professional Schools    4.060
# 690319     7.310                                                  0   7.200
# 690320     3.415          Pharmaceutical Preparation Manufacturing    3.380
# 690321    51.030          Pharmaceutical Preparation Manufacturing   50.310
# 690322    13.820     Surgical and Medical Instrument Manufacturing   13.771
#
# ...

# %%
raw_equity_df['date'] = raw_equity_df['date'].str.replace('_','/')
raw_equity_df
# Out:
#         Unnamed: 0 symbol        date  change  changePercent   close    high  \
# 0                0   PJUL   8/19/2020   0.020        0.00072  27.779  27.840
# 1                1    PIM   8/19/2020  -0.030       -0.00704   4.260   4.260
# 2                2    PJH   8/19/2020  -0.004       -0.00016  25.370  25.450
# 3                3    PJT   8/19/2020  -0.135       -0.00229  59.020  59.670
# 4                4   PKBK   8/19/2020   0.640        0.04992     NaN  13.460
# ...            ...    ...         ...     ...            ...     ...     ...
# 690318      690318    ZVO  12/23/2020  -0.020       -0.00483   4.120   4.270
# 690319      690319    ZSL  12/23/2020  -0.260       -0.03444   7.290   7.380
# 690320      690320   ZYNE  12/23/2020  -0.030       -0.00872   3.410   3.505
# 690321      690321   ZYME  12/23/2020  -2.040       -0.03845  51.010  53.700
# 690322      690322   ZYXI  12/23/2020  -0.380       -0.02678  13.810  14.490
#
# ...

# %%
raw_equity_df.to_csv(r'EQUITY_DATA_COLUMNS.csv')
