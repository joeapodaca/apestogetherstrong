# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv("DATA_MERGED_ON_DATE.csv")
data_df
# Out:
#        symbol        date  change  changePercent   close    high  iexClose  \
# 0        PJUL   8/19/2020   0.020        0.00072  27.779  27.840    27.710
# 1         PIM   8/19/2020  -0.030       -0.00704   4.260   4.260     4.240
# 2         PJH   8/19/2020  -0.004       -0.00016  25.370  25.450    25.365
# 3         PJT   8/19/2020  -0.135       -0.00229  59.020  59.670    58.885
# 4        PKBK   8/19/2020   0.640        0.04992     NaN  13.460    13.460
# ...       ...         ...     ...            ...     ...     ...       ...
# 690318    ZVO  12/23/2020  -0.020       -0.00483   4.120   4.270     4.130
# 690319    ZSL  12/23/2020  -0.260       -0.03444   7.290   7.380     7.310
# 690320   ZYNE  12/23/2020  -0.030       -0.00872   3.410   3.505     3.415
# 690321   ZYME  12/23/2020  -2.040       -0.03845  51.010  53.700    51.030
# 690322   ZYXI  12/23/2020  -0.380       -0.02678  13.810  14.490    13.820
#
#                                                  industry     low  \
# ...

# %%
data_df['change'].isna().sum()
# Out:
# 106939

# %%
690322 - 106939
# Out:
# 583383

# %%
106939/690322
# Out:
# 0.1549117658136348

# %%
data_df['changePercent'].isna().sum()
# Out:
# 107073

# %%
data_df['iexClose'].isna().sum()
# Out:
# 0

# %%
data_df.dtypes
# Out:
# symbol                       object
# date                         object
# change                      float64
# changePercent               float64
# close                       float64
# high                        float64
# iexClose                    float64
# industry                     object
# low                         float64
# marketCap                   float64
# maxChangePercent            float64
# open                        float64
# sector                       object
# volume                        int64
# death                         int64
# deathIncrease                 int64
# hospitalizedIncrease          int64
# hospitalizedCurrently         int64
# negative                      int64
# negativeIncrease              int64
# positive                      int64
# positiveIncrease              int64
# totalTestResults              int64
# totalTestResultsIncrease      int64
# dtype: object

# %%
data_df_dropped_columns = data_df.drop(columns=['change','changePercent','close'])
data_df_dropped_columns
# Out:
#        symbol        date    high  iexClose  \
# 0        PJUL   8/19/2020  27.840    27.710
# 1         PIM   8/19/2020   4.260     4.240
# 2         PJH   8/19/2020  25.450    25.365
# 3         PJT   8/19/2020  59.670    58.885
# 4        PKBK   8/19/2020  13.460    13.460
# ...       ...         ...     ...       ...
# 690318    ZVO  12/23/2020   4.270     4.130
# 690319    ZSL  12/23/2020   7.380     7.310
# 690320   ZYNE  12/23/2020   3.505     3.415
# 690321   ZYME  12/23/2020  53.700    51.030
# 690322   ZYXI  12/23/2020  14.490    13.820
#
#                                                  industry     low  \
# 0                          Investment Trusts/Mutual Funds  27.760
# 1                          Investment Trusts/Mutual Funds   4.230
# 2                                 Financial Conglomerates  25.350
# 3                                Investment Banks/Brokers  58.600
# 4                                          Regional Banks  12.890
# ...

# %%
# save above cell

# %%
symbols_to_drop = []

symbols = data_df_dropped_columns['symbol']
count = 0
for symbol in symbols:
    #print(f'Check1')
    #display(data_df_dropped_columns.loc[data_df_dropped_columns['symbol'] == symbol])
    #temp_df = data_df_dropped_columns.loc[data_df_dropped_columns['symbol'] == symbol]
    #print(f'Check2')
    if ((0 in data_df_dropped_columns.loc[data_df_dropped_columns['symbol'] == symbol]['iexClose']) and (symbol not in symbols_to_drop)):
        print(f'Check3')
        symbols_to_drop.append(symbol)
        print(f'Check4')
    count = count+1
    print(count)
# list(symbols_to_drop)
# Out:
# Check1
# Check2
# Check3
# Check4
# 1
# Check1
# Check2
# 2
# Check1
# Check2
# 3
# Check1
# Check2
# 4
# Check1
# Check2
# 5
# Check1
# Check2
# 6
# Check1
# Check2
# 7
# Check1
# Check2
# 8
# Check1
# Check2
# 9
# Check1
# Check2
# 10
# Check1
# Check2
# 11
# Check1
# Check2
# 12
# Check1
# Check2
# 13
# Check1
# Check2
# 14
# Check1
# Check2
# 15
# Check1
# Check2
# 16
# Check1
# Check2
# 17
# Check1
# Check2
# 18
# Check1
# Check2
# 19
# Check1
# Check2
# 20
# Check1
# Check2
# 21
# Check1
# Check2
# 22
# Check1
# Check2
# 23
# Check1
# Check2
# 24
# Check1
# Check2
# 25
# Check1
# Check2
# 26
# Check1
# Check2
# 27
# Check1
# Check2
# 28
# Check1
# Check2
# 29
# Check1
# Check2
# 30
# Check1
# Check2
# 31
# Check1
# Check2
# 32
# Check1
# Check2
# 33
# Check1
# Check2
# 34
# Check1
# Check2
# 35
# Check1
# Check2
# 36
# Check1
# Check2
# 37
# Check1
# Check2
# 38
# Check1
# Check2
# 39
# Check1
# Check2
# 40
# Check1
# Check2
# 41
# Check1
# Check2
# 42
# Check1
# Check2
# 43
# ...

# %%
# if 0 in data_dfdata_df_dropped_columns then

# %%
symbol_count = len(data_df_dropped_columns["symbol"].unique())
symbol_count
# Out:
# 9336

# %%
8013/9336
# Out:
# 0.8582904884318766

# %%
# per_school_passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]

# %%
# df_dropped_na = df.apply

# %%
list(data_df['symbol'].unique())
# Out:
# ['PJUL',
#  'PIM',
#  'PJH',
#  'PJT',
#  'PKBK',
#  'PICK',
#  'PK',
#  'PJP',
#  'PLBC',
#  'PLAG',
#  'PKE',
#  'PJUN',
#  'PLAB',
#  'PKO',
#  'AAPL',
#  'PLC',
#  'AAL',
#  'PKX',
#  'PKG',
#  'AAMC',
#  'AAON',
#  'PLAN',
#  'PKI',
#  'PLAT',
#  'PKW',
#  'AAAU',
#  'PKOH',
#  'ABB',
#  'PLL',
#  'AA',
#  'ABBV',
#  'PLCY',
#  'ABCB',
#  'A',
#  'AAWW',
#  'AAXN',
#  'PLT',
#  'PLNT',
#  'PLPC',
#  'PLCE',
#  'AAU',
#  'PKB',
#  'PLIN',
#  'AACG',
#  'AB',
#  'AAN',
#  'ABEQ',
#  'AACQU',
#  'AAP',
#  'ABC',
#  'PLUS',
#  'AAXJ',
#  'PLD',
#  'PLOW',
#  'PLXP',
#  'PLW',
#  'ABEV',
#  'PLM',
#  'PLX',
#  'PLYM',
#  'PLUG',
#  'AADR',
#  'PLG',
#  'PLXS',
#  'PMBC',
#  'ABG',
#  'PMAR',
#  'AAT',
#  'PLYA',
#  'AAME',
#  'PLAY',
#  'ABIO',
#  'AC',
#  'PLSE',
#  'PMAY',
#  'PMF',
#  'PMD',
#  'ACAM',
#  'PLMR',
#  'AAOI',
#  'ACB',
#  'ABUS',
#  'ABT',
#  'PLRX',
#  'ACC',
#  'PLTM',
#  'PMO',
#  'PME',
#  'ABM',
#  'ACAMU',
#  'ACAD',
#  'ABMD',
#  'PM',
#  'PML',
#  'ABEO',
# ...

# %%
# Out:
# 9336
