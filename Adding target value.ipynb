# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../apestogetherstrong/COVID_DATA_COLUMNS.csv")
df.head()
# Out:
#          date   death  deathIncrease  hospitalizedIncrease  \
# 0  12/23/2020  317492           3393                  4795
# 1  12/22/2020  314099           3137                  4567
# 2  12/21/2020  310962           1480                  3111
# 3  12/20/2020  309482           1668                  2382
# 4  12/19/2020  307814           2708                  3429
#
#    hospitalizedCurrently  negative  negativeIncrease  positive  \
# 0                 119463  56743142            304962  18367212
# 1                 117777  56438180            268046  18142686
# 2                 115358  56170134            439796  17949678
# 3                 113601  55730338            249266  17770272
# 4                 113914  55481072            200763  17572778
#
#    positiveIncrease  totalTestResults  totalTestResultsIncrease
# 0            224526         241223878                   1791481
# 1            193008         239432397                   1770133
# ...

# %%
df2 = pd.read_csv("../EDA/EQUITY_DATA_COLUMNS.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 symbol       date  change  changePercent   close  \
# 0           0             0   PJUL  8/19/2020   0.020        0.00072  27.779
# 1           1             1    PIM  8/19/2020  -0.030       -0.00704   4.260
# 2           2             2    PJH  8/19/2020  -0.004       -0.00016  25.370
# 3           3             3    PJT  8/19/2020  -0.135       -0.00229  59.020
# 4           4             4   PKBK  8/19/2020   0.640        0.04992     NaN
#
#     high  iexClose                        industry    low     marketCap  \
# 0  27.84    27.710  Investment Trusts/Mutual Funds  27.76  1.160650e+08
# 1   4.26     4.240  Investment Trusts/Mutual Funds   4.23  2.190971e+08
# 2  25.45    25.365         Financial Conglomerates  25.35  1.001957e+10
# 3  59.67    58.885        Investment Banks/Brokers  58.60  1.415189e+09
# 4  13.46    13.460                  Regional Banks  12.89  1.594889e+08
#
#    maxChangePercent    open         sector  volume
# ...

# %%
del df2['Unnamed: 0']
df2.head()
# Out:
#    Unnamed: 0.1 symbol       date  change  changePercent   close   high  \
# 0             0   PJUL  8/19/2020   0.020        0.00072  27.779  27.84
# 1             1    PIM  8/19/2020  -0.030       -0.00704   4.260   4.26
# 2             2    PJH  8/19/2020  -0.004       -0.00016  25.370  25.45
# 3             3    PJT  8/19/2020  -0.135       -0.00229  59.020  59.67
# 4             4   PKBK  8/19/2020   0.640        0.04992     NaN  13.46
#
#    iexClose                        industry    low     marketCap  \
# 0    27.710  Investment Trusts/Mutual Funds  27.76  1.160650e+08
# 1     4.240  Investment Trusts/Mutual Funds   4.23  2.190971e+08
# 2    25.365         Financial Conglomerates  25.35  1.001957e+10
# 3    58.885        Investment Banks/Brokers  58.60  1.415189e+09
# 4    13.460                  Regional Banks  12.89  1.594889e+08
#
#    maxChangePercent    open         sector  volume
# 0            0.0494  27.779  Miscellaneous    3283
# ...

# %%
del df2['Unnamed: 0.1']
df2.head()
# Out:
#   symbol       date  change  changePercent   close   high  iexClose  \
# 0   PJUL  8/19/2020   0.020        0.00072  27.779  27.84    27.710
# 1    PIM  8/19/2020  -0.030       -0.00704   4.260   4.26     4.240
# 2    PJH  8/19/2020  -0.004       -0.00016  25.370  25.45    25.365
# 3    PJT  8/19/2020  -0.135       -0.00229  59.020  59.67    58.885
# 4   PKBK  8/19/2020   0.640        0.04992     NaN  13.46    13.460
#
#                          industry    low     marketCap  maxChangePercent  \
# 0  Investment Trusts/Mutual Funds  27.76  1.160650e+08            0.0494
# 1  Investment Trusts/Mutual Funds   4.23  2.190971e+08           -0.3185
# 2         Financial Conglomerates  25.35  1.001957e+10            0.0152
# 3        Investment Banks/Brokers  58.60  1.415189e+09            0.7452
# 4                  Regional Banks  12.89  1.594889e+08            3.8561
#
#      open         sector  volume
# 0  27.779  Miscellaneous    3283
# 1   4.260  Miscellaneous   31824
# ...

# %%
provisional_db_merged = pd.merge(df, df2, how='inner', on = 'date')

# %%
provisional_db_merged.head()
# Out:
#          date   death  deathIncrease  hospitalizedIncrease  \
# 0  12/23/2020  317492           3393                  4795
# 1  12/23/2020  317492           3393                  4795
# 2  12/23/2020  317492           3393                  4795
# 3  12/23/2020  317492           3393                  4795
# 4  12/23/2020  317492           3393                  4795
#
#    hospitalizedCurrently  negative  negativeIncrease  positive  \
# 0                 119463  56743142            304962  18367212
# 1                 119463  56743142            304962  18367212
# 2                 119463  56743142            304962  18367212
# 3                 119463  56743142            304962  18367212
# 4                 119463  56743142            304962  18367212
#
#    positiveIncrease  totalTestResults  ...   close    high  iexClose  \
# 0            224526         241223878  ...   33.38   33.78     33.39
# 1            224526         241223878  ...   55.75   56.95     55.80
# ...

# %%
provisional_db_merged.shape
# Out:
# (690323, 24)

# %%
provisional_db_merged.to_csv(r'provisional_db.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19660/3924788961.py in <module>
# ----> 1 provisional_db_merged.to_csv(r'provisional_db.csv')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ...

# %%
## Adding new column 'Change in  hospitalized'
provisional_db_merged['diff'] = provisional_db_merged.sort_values(['date', 'pos itive']).groupby('date')['positive'].diff()
provisional_db_merged.head()
# Out:
#          date   death  deathIncrease  hospitalizedIncrease  \
# 0  12/23/2020  317492           3393                  4795
# 1  12/23/2020  317492           3393                  4795
# 2  12/23/2020  317492           3393                  4795
# 3  12/23/2020  317492           3393                  4795
# 4  12/23/2020  317492           3393                  4795
#
#    hospitalizedCurrently  negative  negativeIncrease  positive  \
# 0                 119463  56743142            304962  18367212
# 1                 119463  56743142            304962  18367212
# 2                 119463  56743142            304962  18367212
# 3                 119463  56743142            304962  18367212
# 4                 119463  56743142            304962  18367212
#
#    positiveIncrease  totalTestResults  ...    high iexClose  \
# 0            224526         241223878  ...   33.78    33.39
# 1            224526         241223878  ...   56.95    55.80
# ...

# %%
provisional_db_merged.head()
# Out:
#          date   death  deathIncrease  hospitalizedIncrease  \
# 0  12/23/2020  317492           3393                  4795
# 1  12/23/2020  317492           3393                  4795
# 2  12/23/2020  317492           3393                  4795
# 3  12/23/2020  317492           3393                  4795
# 4  12/23/2020  317492           3393                  4795
#
#    hospitalizedCurrently  negative  negativeIncrease  positive  \
# 0                 119463  56743142            304962  18367212
# 1                 119463  56743142            304962  18367212
# 2                 119463  56743142            304962  18367212
# 3                 119463  56743142            304962  18367212
# 4                 119463  56743142            304962  18367212
#
#    positiveIncrease  totalTestResults  ...   close    high  iexClose  \
# 0            224526         241223878  ...   33.38   33.78     33.39
# 1            224526         241223878  ...   55.75   56.95     55.80
# ...

# %%
provisional_db_merged['Variation'].value_counts()
# Out:
# Series([], Name: Variation, dtype: int64)
